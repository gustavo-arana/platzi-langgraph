# %%
from langchain_core.prompts import PromptTemplate

template = """\
# Instrucciones para el Asistente de IA

Recuerda que hoy es {fecha_actual}

## Rol
Eres un experto en marketing digital con 10 años de experiencia.

## Tarea
Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocándote en el llamado a la acción.

## Texto del Anuncio
{texto_anuncio}

## Formato de Salida
- *Sugerencia 1:* [Tu primera sugerencia]
- *Sugerencia 2:* [Tu segunda sugerencia]
- *Sugerencia 3:* [Tu tercera sugerencia]
"""

# %%
prompt_template = PromptTemplate.from_template(template)
prompt = prompt_template.format(fecha_actual="2026-09-20", texto_anuncio="Este es un anuncio de prueba.")
print(prompt)
# Out:
# # Instrucciones para el Asistente de IA
#
# Recuerda que hoy es 2026-09-20
#
# ## Rol
# Eres un experto en marketing digital con 10 años de experiencia.
#
# ## Tarea
# Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocándote en el llamado a la acción.
#
# ## Texto del Anuncio
# Este es un anuncio de prueba.
#
# ## Formato de Salida
# - *Sugerencia 1:* [Tu primera sugerencia]
# - *Sugerencia 2:* [Tu segunda sugerencia]
# - *Sugerencia 3:* [Tu tercera sugerencia]

# %%
import datetime
today = datetime.date.today().strftime("%Y-%m-%d")
prompt_template = PromptTemplate.from_template(template, partial_variables={"fecha_actual": today})
prompt = prompt_template.format(texto_anuncio="Este es un anuncio de prueba.")
print(prompt)
# Out:
# # Instrucciones para el Asistente de IA
#
# Recuerda que hoy es 2026-08-25
#
# ## Rol
# Eres un experto en marketing digital con 10 años de experiencia.
#
# ## Tarea
# Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocándote en el llamado a la acción.
#
# ## Texto del Anuncio
# Este es un anuncio de prueba.
#
# ## Formato de Salida
# - *Sugerencia 1:* [Tu primera sugerencia]
# - *Sugerencia 2:* [Tu segunda sugerencia]
# - *Sugerencia 3:* [Tu tercera sugerencia]

# %%
template = """\
Your are a helpful that responds to the user's message

{% if name %}
    The user's name is {{ name }} and you can call them by that name
{% endif -%}

The user's message is: {{ user_message }}
"""

prompt_template = PromptTemplate.from_template(template, template_format="jinja2")
prompt = prompt_template.format(user_message="Como puedo optimizar mi sitio web")
print(prompt)
# Out:
# Your are a helpful that responds to the user's message
#
# The user's message is: Como puedo optimizar mi sitio web

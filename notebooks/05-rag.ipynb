# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("openai:gpt-5-nano", temperature=1)
response = llm.invoke("Hola, como estas? Que dia es hoy?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ¡Hola! Estoy bien, gracias. ¿Y tú? Hoy es lunes, 24 de agosto de 2026. ¿En qué te gustaría que te ayude hoy?

# %%
#openai_vector_store_ids = [
# "vs_6a8bfc14c78c8191ad5cb84e42001e5f",
#]

file_search_tool = {
    "type": "file_search",
    "vector_store_ids": ["vs_6a8bfc14c78c8191ad5cb84e42001e5f"],
}

llm_with_tools = llm.bind_tools([file_search_tool])

# %%
response = llm_with_tools.invoke("¿Como mejoro el rendimiento de mi website?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ...

# %%
response.text
# Out:
# 'Aquí tienes un plan práctico y respaldado por buenas prácticas para mejorar el rendimiento de tu website. He agrupado acciones por impacto y con herramientas recomendadas.\n\nQué medir y por dónde empezar\n- Realiza una auditoría inicial con herramientas de rendimiento (Lighthouse, PageSpeed Insights, WebPageTest) y consulta datos de usuarios reales y de laboratorio (CrUX). Estas herramientas te muestran oportunidades específicas y métricas clave a mejorar. \n- Distingue entre datos de laboratorio (medidos en condiciones controladas) y datos reales de usuarios para entender dónde están los cuellos de botella. \n- Si quieres entender y priorizar las mejoras, consulta guías como el Mobile Site Speed Playbook de Google y estilos de presupuesto de rendimiento para incorporar en tu flujo de trabajo. \ue200filecite\ue202turn0file0\ue202turn0file5\ue201\n\nAcciones prácticas de alto impacto\n1) Optimiza el renderizado inicial\n- Elimina o difiere recursos que bloquean el render (CSS/JS crí
# ...

# %%
response = llm.invoke("¿Como mejoro el rendimiento de mi website?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Claro. Aquí tienes un plan práctico y accionable para mejorar el rendimiento de tu website. Puedes aplicar estas ideas en función de tu pila (HTML/CSS/JS puro, frameworks como React/Vue/Next, WordPress, etc.).
#
# 1) Mide y establece metas
# - Métricas clave (Core Web Vitals): LCP (Largest Contentful Paint) ≤ 2.5 s, CLS (Cumulative Layout Shift) ≤ 0.1, TBT (Total Blocking Time) / FID ≤ 300 ms.
# - Herramientas útiles: Lighthouse (en Chrome DevTools), PageSpeed Insights, WebPageTest, GTmetrix.
# - Define un presupuesto de rendimiento (por ejemplo: LCP < 2.5 s, CLS < 0.1, tamaño inicial de HTML < 150 KB, etc.) y haz pruebas periódicas.
#
# 2) Optimiza la entrega y la red
# - Caché y CDN
#   - Activa caching adecuado en el servidor (Cache-Control, ETag) y usa caching a nivel de CDN/edge para contenidos estáticos.
#   - Considera un CDN para servir imágenes, JS y CSS desde ubicaciones cercanas.
# ...

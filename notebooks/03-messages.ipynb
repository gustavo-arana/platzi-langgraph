# %%
from langchain_core.messages import AIMessage

ai_msg = AIMessage(content="Message from the AI")
ai_msg.text
# Out:
# 'Message from the AI'

# %%
from langchain_core.messages import HumanMessage

human_msg = HumanMessage(content="Message from the human")
human_msg.text
# Out:
# 'Message from the human'

# %%
history = [ai_msg, human_msg]
history

for m in history:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Message from the AI
# ================================ Human Message =================================
#
# Message from the human

# %%
history += [AIMessage(content="Another message from the AI")]

# %%
for m in history:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Message from the AI
# ================================ Human Message =================================
#
# Message from the human
# ================================== Ai Message ==================================
#
# Another message from the AI
